# %%
import sys
sys.path.append(r'C:\\Users\\swavi\\Documents\\GitHub\\F1-Stop-Strategy')
from SetUpData.loadSession import getSession
from SetUpData.settingUpData import calculatingDriverLaps

import fastf1
year = 2025
races = fastf1.get_event_schedule(2025,include_testing=False)
racesInYear = races.shape[0]
for i in range(1,racesInYear+1):
    track = races.iloc[i-1,2]
    getSession(year,i)
    calculatingDriverLaps(year,i,track)
    print(f"Added data in for race: {track}")
# Out:
# Added data in for race: Melbourne
# Added data in for race: Shanghai
# Added data in for race: Suzuka
# Added data in for race: Sakhir
# Added data in for race: Jeddah
# Added data in for race: Miami Gardens
# Added data in for race: Imola
# Added data in for race: Monaco
# Added data in for race: Barcelona
# Added data in for race: Montréal
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      11 track = races.iloc[i-1,2]
#      12 getSession(year,i)
# ---> 13 calculatingDriverLaps(year,i,track)
#      14 print(f"Added data in for race: {track}")
#
# File C:\\Users\\swavi\\Documents\\GitHub\\F1-Stop-Strategy\SetUpData\settingUpData.py:120, in calculatingDriverLaps(year, raceNumber, track)
#     117 lapTelemetry["Y"] /= 10
#     118 lapTelemetry = lapTelemetry.reset_index(drop=True)
# --> 120 lapTelemetry = identifyCorner(lapTelemetry, cornerData)
# ...
