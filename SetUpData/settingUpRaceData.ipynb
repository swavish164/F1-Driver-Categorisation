# %%
import sys
sys.path.append(r'C:\\Users\\swavi\\Documents\\GitHub\\F1-Stop-Strategy')
from SetUpData.loadSession import getSession
from SetUpData.settingUpData import calculatingDriverLaps

import fastf1
year = 2025
races = fastf1.get_event_schedule(2025,include_testing=False)
racesInYear = races.shape[0]
#for i in range(0,1):
    #track = races.iloc[i][2]
    #getSession(year,i+1)
    #print("Got session")
    #calculatingDriverLaps(year,i+1,track)


track = races.iloc[12][2]    
getSession(2025,12)
calculatingDriverLaps(year,12,track)
# Out:
# C:\Users\swavi\AppData\Local\Temp\ipykernel_21944\1524164419.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   track = races.iloc[12][2]
# Added race to database
# Added driverALB to database
# Added in lap:  1 1 8.0
# Added lap data for lap:  1
# Added in lap:  1 1 9.0
# Added lap data for lap:  2
# Added in lap:  1 1 10.0
# Added lap data for lap:  3
# Set attacking to true for:  1 3
# Added in lap:  1 1 11.0
# Added lap data for lap:  4
# Set attacking to true for:  1 4
# Added in lap:  1 1 12.0
# Added lap data for lap:  5
# Set attacking to true for:  1 5
# Added in lap:  1 1 23.0
# Added lap data for lap:  6
# Added in lap:  1 1 24.0
# Added lap data for lap:  7
# Added in lap:  1 1 25.0
# Added lap data for lap:  8
# Added in lap:  1 1 26.0
# Added lap data for lap:  9
# ...
